# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-2/trim-filter-messages.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/58239435-lesson-4-trim-and-filter-messages)

# %% [markdown]
# # Filtering and trimming messages
#
# ## Review
#
# Now, we have a deeper understanding of a few things:
#
# * How to customize the graph state schema
# * How to define custom state reducers
# * How to use multiple graph state schemas
#
# ## Goals
#
# Now, we can start using these concepts with models in LangGraph!
#
# In the next few sessions, we'll build towards a chatbot that has long-term memory.
#
# Because our chatbot will use messages, let's first talk a bit more about advanced ways to work with messages in graph state.

# %% [markdown]
# We'll use [LangSmith](https://docs.langchain.com/langsmith/home) for [tracing](https://docs.langchain.com/langsmith/observability-concepts).
#
# We'll log to a project, `langchain-academy`.

# %% [markdown]
# ## Messages as state
#
# First, let's define some messages.

# %%
from pprint import pprint
from langchain_core.messages import AIMessage, HumanMessage
messages = [AIMessage(f"So you said you were researching ocean mammals?", name="Bot")]
messages.append(HumanMessage(f"Yes, I know about whales. But what others should I learn about?", name="Lance"))

for m in messages:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?

# %% [markdown]
# Recall we can pass them to a chat model.

# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="qwen3:14b", temperature=0)
llm.invoke(messages)
# Out:
# AIMessage(content='That\'s a great question! While whales are fascinating, the ocean is home to a wide variety of **marine mammals** with unique adaptations and behaviors. Here are some key groups and species to explore beyond whales:\n\n---\n\n### **1. Cetaceans (Whales, Dolphins, and Porpoises)**\n- **Dolphins**: Intelligent and social, with species like the **bottlenose dolphin**, **spinner dolphin**, and **Amazon river dolphin** (which lives in freshwater rivers).\n- **Porpoises**: Smaller and less social than dolphins, like the **harbor porpoise** and **finless porpoise**.\n- **Orca (Killer Whale)**: A type of dolphin, known for hunting in pods and their striking black-and-white coloration.\n- **Narwhal**: A toothed whale with a long, spiral tusk (actually a tooth) used for sensing the environment.\n- **Sperm Whale**: Known for deep dives and their role in the **sperm oil** trade (now protected).\n- **Humpback Whale**: Famous for their **complex songs** and long migrations.\n\n---\n\n### **2. Pinnipeds (Seals, Sea Lions, and Walruses)**\n- **Seals**: Includes the **harbor seal**, **fur seal**, and **elephant seal** (which can grow to 5 meters long!).\n- **Sea Lions**: More agile in water, like the **California sea lion** and **Steller sea lion**.\n- **Walrus**: Known for their **tusks** (used for walking on ice and fighting) and **mustaches** (sensory whiskers).\n- **Polar Bear**: Though technically a bear, they spend much of their lives in the Arctic Ocean, hunting seals on sea ice.\n\n---\n\n### **3. Sirenians (Manatees and Dugongs)**\n- **Manatees**: Gentle giants with a slow, herbivorous lifestyle. Includes the **West Indian manatee** and **African manatee**.\n- **Dugongs**: Often called "sea cows," they graze on seagrass and are found in the Indo-Pacific region.\n\n---\n\n### **4. Other Unique Marine Mammals**\n- **Sea Otter**: A **mustelid** (relative of weasels) that uses tools (like rocks) to crack open shellfish.\n- **Hippopotamus**: Though mostly freshwater, they spend hours in rivers and lakes, and their **massive size** (up to 3,000 kg) makes them one of the most dangerous animals in Africa.\n- **Sperm Whale**: Already mentioned, but worth noting their role in the **deep-sea ecosystem** as apex predators.\n\n---\n\n### **Why Explore These?**\n- **Adaptations**: Many have evolved to survive in extreme environments (e.g., polar bears in the Arctic, manatees in warm coastal waters).\n- **Conservation**: Some species are endangered due to habitat loss, pollution, or hunting (e.g., **Vaquita**, a critically endangered porpoise).\n- **Cultural Significance**: Dolphins and whales feature in myths, art, and even scientific research (e.g., **whale songs** studied for their complexity).\n\n---\n\nWould you like to dive deeper into any of these groups or explore their conservation status? 🐬🌊', additional_kwargs={}, response_metadata={'model': 'qwen3:14b', 'created_at': '2026-03-28T11:59:50.949139537Z', 'done': True, 'done_reason': 'stop', 'total_duration': 736723026849, 'load_duration': 143695152, 'prompt_eval_count': 39, 'prompt_eval_duration': 439197250, 'eval_count': 1400, 'eval_duration': 735450407060, 'logprobs': None, 'model_name': 'qwen3:14b', 'model_provider': 'ollama'}, id='lc_run--019d3445-5ccf-7133-93f1-b1b22f504c76-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 39, 'output_tokens': 1400, 'total_tokens': 1439})

# %% [markdown]
# We can run our chat model in a simple graph with `MessagesState`.

# %%
from IPython.display import Image, display
from langgraph.graph import MessagesState
from langgraph.graph import StateGraph, START, END

# Node
def chat_model_node(state: MessagesState):
    return {"messages": llm.invoke(state["messages"])}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
output = graph.invoke({'messages': messages})
for m in output['messages']:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# That's a great question! While whales are fascinating, the ocean is home to a wide variety of **marine mammals** with unique adaptations and behaviors. Here are some key groups and species to explore beyond whales:
#
# ---
#
# ### **1. Cetaceans (Whales, Dolphins, and Porpoises)**
# - **Dolphins**: Intelligent and social, with species like the **bottlenose dolphin**, **spinner dolphin**, and **Amazon river dolphin** (which lives in freshwater rivers).
# - **Porpoises**: Smaller and less social than dolphins, like the **harbor porpoise** and **finless porpoise**.
# - **Orca (Killer Whale)**: A type of dolphin, known for hunting in pods and their striking black-and-white coloration.
# - **Narwhal**: A toothed whale with a long, spiral tusk (actually a tooth) used for sensing the environment.
# - **Sperm Whale**: Known for deep dives and their role in the **sperm oil** trade (now protected).
# - **Humpback Whale**: Famous for their **complex songs** and long migrations.
#
# ---
#
# ### **2. Pinnipeds (Seals, Sea Lions, and Walruses)**
# - **Seals**: Includes the **harbor seal**, **fur seal**, and **elephant seal** (which can grow to 5 meters long!).
# - **Sea Lions**: More agile in water, like the **California sea lion** and **Steller sea lion**.
# - **Walrus**: Known for their **tusks** (used for walking on ice and fighting) and **mustaches** (sensory whiskers).
# - **Polar Bear**: Though technically a bear, they spend much of their lives in the Arctic Ocean, hunting seals on sea ice.
#
# ---
#
# ### **3. Sirenians (Manatees and Dugongs)**
# - **Manatees**: Gentle giants with a slow, herbivorous lifestyle. Includes the **West Indian manatee** and **African manatee**.
# - **Dugongs**: Often called "sea cows," they graze on seagrass and are found in the Indo-Pacific region.
#
# ---
#
# ### **4. Other Unique Marine Mammals**
# - **Sea Otter**: A **mustelid** (relative of weasels) that uses tools (like rocks) to crack open shellfish.
# - **Hippopotamus**: Though mostly freshwater, they spend hours in rivers and lakes, and their **massive size** (up to 3,000 kg) makes them one of the most dangerous animals in Africa.
# - **Sperm Whale**: Already mentioned, but worth noting their role in the **deep-sea ecosystem** as apex predators.
#
# ---
#
# ### **Why Explore These?**
# - **Adaptations**: Many have evolved to survive in extreme environments (e.g., polar bears in the Arctic, manatees in warm coastal waters).
# - **Conservation**: Some species are endangered due to habitat loss, pollution, or hunting (e.g., **Vaquita**, a critically endangered porpoise).
# - **Cultural Significance**: Dolphins and whales feature in myths, art, and even scientific research (e.g., **whale songs** studied for their complexity).
#
# ---
#
# Would you like to dive deeper into any of these groups or explore their conservation status? 🐬🌊

# %% [markdown]
# ## Reducer
#
# A practical challenge when working with messages is managing long-running conversations.
#
# Long-running conversations result in high token usage and latency if we are not careful, because we pass a growing list of messages to the model.
#
# We have a few ways to address this.
#
# First, recall the trick we saw using `RemoveMessage` and the `add_messages` reducer.

# %%
from langchain_core.messages import RemoveMessage

# Nodes
def filter_messages(state: MessagesState):
    # Delete all but the 2 most recent messages
    delete_messages = [RemoveMessage(id=m.id) for m in state["messages"][:-2]]
    return {"messages": delete_messages}

def chat_model_node(state: MessagesState):    
    return {"messages": [llm.invoke(state["messages"])]}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("filter", filter_messages)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "filter")
builder.add_edge("filter", "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
# Message list with a preamble
messages = [AIMessage("Hi.", name="Bot", id="1")]
messages.append(HumanMessage("Hi.", name="Lance", id="2"))
messages.append(AIMessage("So you said you were researching ocean mammals?", name="Bot", id="3"))
messages.append(HumanMessage("Yes, I know about whales. But what others should I learn about?", name="Lance", id="4"))

# Invoke
output = graph.invoke({'messages': messages})
for m in output['messages']:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# That's a great start! Ocean mammals are incredibly diverse, and there are many fascinating species beyond whales. Here's a breakdown of the main groups and some standout examples to explore:
#
# ---
#
# ### **1. Cetaceans (Whales, Dolphins, Porpoises)**
# - **Whales**: Beyond the well-known blue whale, consider the **sperm whale** (uses echolocation to hunt giant squid), **humpback whale** (known for complex songs), and **fin whale** (second-largest animal on Earth).
# - **Dolphins**: The **orca (killer whale)** is actually a dolphin, but it’s a top predator in the ocean. The **bottlenose dolphin** is a social favorite, while the **Amazon river dolphin** lives in freshwater but is still a cetacean.
# - **Porpoises**: Smaller and more shy than dolphins, like the **harbor porpoise** and the **vaquita** (critically endangered, with fewer than 30 individuals left).
#
# ---
#
# ### **2. Pinnipeds (Seals, Sea Lions, Walruses)**
# - **Seals**: The **fur seal** (once hunted to near extinction), **elephant seal** (largest pinniped), and **Weddell seal** (lives in Antarctic ice).
# - **Sea Lions**: The **California sea lion** is playful and often seen in coastal areas, while the **Steller sea lion** is a powerful predator.
# - **Walruses**: Known for their tusks and mustaches, they use them to haul themselves out of water and fight rivals. The **Pacific walrus** is a key species in Arctic ecosystems.
#
# ---
#
# ### **3. Sirenians (Manatees, Dugongs)**
# - **Manatees**: The **West Indian manatee** and **African manatee** are gentle giants that graze on seagrass. They’re often called "sea cows" and are vulnerable to boat strikes.
# - **Dugongs**: Found in tropical coastal waters, they’re closely related to manatees but have a more streamlined body. They’re also called "sea cows" and are important for maintaining seagrass beds.
#
# ---
#
# ### **4. Other Marine Mammals**
# - **Polar Bears**: Though technically land mammals, they spend much of their lives hunting seals on sea ice. They’re apex predators in the Arctic.
# - **Sea Otters**: These playful, furry mammals use tools (like rocks) to crack open shellfish. They’re keystone species that help maintain healthy kelp forests.
# - **Monk Seals**: The **Hawaiian monk seal** and **Mediterranean monk seal** are critically endangered and live in remote coastal areas.
# - **Hippos**: While they’re semi-aquatic and live in freshwater, they’re sometimes included in marine mammal discussions due to their time in rivers and lakes.
#
# ---
#
# ### **Fun Facts to Explore**
# - **Narwhals**: Known as the "unicorns of the sea," their spiral tusks are actually elongated teeth.
# - **Beluga Whales**: These "canaries of the sea" have a unique, melodic vocalizations and live in Arctic waters.
# - **Sperm Whales**: They dive deeper than any other animal (over 3,000 feet!) to hunt squid.
# - **Vaquita**: The world’s most endangered marine mammal, with fewer than 30 individuals left.
#
# ---
#
# ### **Why Study Them?**
# - **Conservation**: Many species are threatened by pollution, climate change, and overfishing (e.g., the vaquita, northern fur seal).
# - **Ecology**: They play critical roles in ocean ecosystems, from controlling prey populations to maintaining habitat health.
# - **Cultural Significance**: Whales and dolphins have inspired myths, art, and scientific curiosity for centuries.
#
# ---
#
# If you're interested, I can dive deeper into specific species or share resources for further learning! 🐬🌊

# %% [markdown]
# ## Filtering messages
#
# If you don't need or want to modify the graph state, you can just filter the messages you pass to the chat model.
#
# For example, just pass in a filtered list: `llm.invoke(messages[-1:])` to the model.

# %%
# Node
def chat_model_node(state: MessagesState):
    return {"messages": [llm.invoke(state["messages"][-1:])]}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# Let's take our existing list of messages, append the above LLM response, and append a follow-up question.

# %%
messages.append(output['messages'][-1])
messages.append(HumanMessage(f"Tell me more about Narwhals!", name="Lance"))

# %%
for m in messages:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# Hi.
# ================================ Human Message =================================
# Name: Lance
#
# Hi.
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# That's a great start! Ocean mammals are incredibly diverse, and there are many fascinating species beyond whales. Here's a breakdown of the main groups and some standout examples to explore:
#
# ---
#
# ### **1. Cetaceans (Whales, Dolphins, Porpoises)**
# - **Whales**: Beyond the well-known blue whale, consider the **sperm whale** (uses echolocation to hunt giant squid), **humpback whale** (known for complex songs), and **fin whale** (second-largest animal on Earth).
# - **Dolphins**: The **orca (killer whale)** is actually a dolphin, but it’s a top predator in the ocean. The **bottlenose dolphin** is a social favorite, while the **Amazon river dolphin** lives in freshwater but is still a cetacean.
# - **Porpoises**: Smaller and more shy than dolphins, like the **harbor porpoise** and the **vaquita** (critically endangered, with fewer than 30 individuals left).
#
# ---
#
# ### **2. Pinnipeds (Seals, Sea Lions, Walruses)**
# - **Seals**: The **fur seal** (once hunted to near extinction), **elephant seal** (largest pinniped), and **Weddell seal** (lives in Antarctic ice).
# - **Sea Lions**: The **California sea lion** is playful and often seen in coastal areas, while the **Steller sea lion** is a powerful predator.
# - **Walruses**: Known for their tusks and mustaches, they use them to haul themselves out of water and fight rivals. The **Pacific walrus** is a key species in Arctic ecosystems.
#
# ---
#
# ### **3. Sirenians (Manatees, Dugongs)**
# - **Manatees**: The **West Indian manatee** and **African manatee** are gentle giants that graze on seagrass. They’re often called "sea cows" and are vulnerable to boat strikes.
# - **Dugongs**: Found in tropical coastal waters, they’re closely related to manatees but have a more streamlined body. They’re also called "sea cows" and are important for maintaining seagrass beds.
#
# ---
#
# ### **4. Other Marine Mammals**
# - **Polar Bears**: Though technically land mammals, they spend much of their lives hunting seals on sea ice. They’re apex predators in the Arctic.
# - **Sea Otters**: These playful, furry mammals use tools (like rocks) to crack open shellfish. They’re keystone species that help maintain healthy kelp forests.
# - **Monk Seals**: The **Hawaiian monk seal** and **Mediterranean monk seal** are critically endangered and live in remote coastal areas.
# - **Hippos**: While they’re semi-aquatic and live in freshwater, they’re sometimes included in marine mammal discussions due to their time in rivers and lakes.
#
# ---
#
# ### **Fun Facts to Explore**
# - **Narwhals**: Known as the "unicorns of the sea," their spiral tusks are actually elongated teeth.
# - **Beluga Whales**: These "canaries of the sea" have a unique, melodic vocalizations and live in Arctic waters.
# - **Sperm Whales**: They dive deeper than any other animal (over 3,000 feet!) to hunt squid.
# - **Vaquita**: The world’s most endangered marine mammal, with fewer than 30 individuals left.
#
# ---
#
# ### **Why Study Them?**
# - **Conservation**: Many species are threatened by pollution, climate change, and overfishing (e.g., the vaquita, northern fur seal).
# - **Ecology**: They play critical roles in ocean ecosystems, from controlling prey populations to maintaining habitat health.
# - **Cultural Significance**: Whales and dolphins have inspired myths, art, and scientific curiosity for centuries.
#
# ---
#
# If you're interested, I can dive deeper into specific species or share resources for further learning! 🐬🌊
# ================================ Human Message =================================
# Name: Lance
#
# Tell me more about Narwhals!

# %%
# Invoke, using message filtering
output = graph.invoke({'messages': messages})
for m in output['messages']:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# Hi.
# ================================ Human Message =================================
# Name: Lance
#
# Hi.
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# That's a great start! Ocean mammals are incredibly diverse, and there are many fascinating species beyond whales. Here's a breakdown of the main groups and some standout examples to explore:
#
# ---
#
# ### **1. Cetaceans (Whales, Dolphins, Porpoises)**
# - **Whales**: Beyond the well-known blue whale, consider the **sperm whale** (uses echolocation to hunt giant squid), **humpback whale** (known for complex songs), and **fin whale** (second-largest animal on Earth).
# - **Dolphins**: The **orca (killer whale)** is actually a dolphin, but it’s a top predator in the ocean. The **bottlenose dolphin** is a social favorite, while the **Amazon river dolphin** lives in freshwater but is still a cetacean.
# - **Porpoises**: Smaller and more shy than dolphins, like the **harbor porpoise** and the **vaquita** (critically endangered, with fewer than 30 individuals left).
#
# ---
#
# ### **2. Pinnipeds (Seals, Sea Lions, Walruses)**
# - **Seals**: The **fur seal** (once hunted to near extinction), **elephant seal** (largest pinniped), and **Weddell seal** (lives in Antarctic ice).
# - **Sea Lions**: The **California sea lion** is playful and often seen in coastal areas, while the **Steller sea lion** is a powerful predator.
# - **Walruses**: Known for their tusks and mustaches, they use them to haul themselves out of water and fight rivals. The **Pacific walrus** is a key species in Arctic ecosystems.
#
# ---
#
# ### **3. Sirenians (Manatees, Dugongs)**
# - **Manatees**: The **West Indian manatee** and **African manatee** are gentle giants that graze on seagrass. They’re often called "sea cows" and are vulnerable to boat strikes.
# - **Dugongs**: Found in tropical coastal waters, they’re closely related to manatees but have a more streamlined body. They’re also called "sea cows" and are important for maintaining seagrass beds.
#
# ---
#
# ### **4. Other Marine Mammals**
# - **Polar Bears**: Though technically land mammals, they spend much of their lives hunting seals on sea ice. They’re apex predators in the Arctic.
# - **Sea Otters**: These playful, furry mammals use tools (like rocks) to crack open shellfish. They’re keystone species that help maintain healthy kelp forests.
# - **Monk Seals**: The **Hawaiian monk seal** and **Mediterranean monk seal** are critically endangered and live in remote coastal areas.
# - **Hippos**: While they’re semi-aquatic and live in freshwater, they’re sometimes included in marine mammal discussions due to their time in rivers and lakes.
#
# ---
#
# ### **Fun Facts to Explore**
# - **Narwhals**: Known as the "unicorns of the sea," their spiral tusks are actually elongated teeth.
# - **Beluga Whales**: These "canaries of the sea" have a unique, melodic vocalizations and live in Arctic waters.
# - **Sperm Whales**: They dive deeper than any other animal (over 3,000 feet!) to hunt squid.
# - **Vaquita**: The world’s most endangered marine mammal, with fewer than 30 individuals left.
#
# ---
#
# ### **Why Study Them?**
# - **Conservation**: Many species are threatened by pollution, climate change, and overfishing (e.g., the vaquita, northern fur seal).
# - **Ecology**: They play critical roles in ocean ecosystems, from controlling prey populations to maintaining habitat health.
# - **Cultural Significance**: Whales and dolphins have inspired myths, art, and scientific curiosity for centuries.
#
# ---
#
# If you're interested, I can dive deeper into specific species or share resources for further learning! 🐬🌊
# ================================ Human Message =================================
# Name: Lance
#
# Tell me more about Narwhals!
# ================================== Ai Message ==================================
#
# Narwhals are fascinating marine mammals that inhabit the Arctic waters, and they’re often called the "unicorns of the sea" due to their iconic, spiral tusk. Here's a detailed overview of these enigmatic creatures:
#
# ---
#
# ### **Scientific Classification**
# - **Scientific Name**: *Monodon monoceros*
# - **Family**: Monodontidae (alongside belugas)
# - **Order**: Cetacea (whales, dolphins, and porpoises)
#
# ---
#
# ### **Physical Characteristics**
# - **Size**: Adults measure **4.5–5.5 meters (15–18 feet)** in length and weigh **800–1,600 kg (1,800–3,500 lbs)**.
# - **Tusk**: The most striking feature is the **elongated, spiral tusk**, which is actually a **modified canine tooth**. It grows only in males (though some females may have smaller tusks) and can reach **up to 2.5 meters (8 feet)** in length. The tusk is highly sensitive, containing **nerve endings** that help detect changes in water temperature, salinity, and pressure—possibly aiding in navigation or finding prey.
# - **Coloration**: Their skin is **mottled gray and white**, with a **dark dorsal patch** and a **lighter belly**.
#
# ---
#
# ### **Habitat and Distribution**
# - **Range**: Found in the **Arctic Ocean**, particularly in **Canadian Arctic, Greenland, and Russia**.
# - **Migration**: They migrate seasonally to **Baffin Bay and Davis Strait** during summer to feed, then return to **frozen Arctic waters** in winter.
# - **Deep Divers**: Narwhals are **deep-diving specialists**, capable of plunging to **1,500 meters (4,900 feet)** and holding their breath for **up to 25 minutes**.
#
# ---
#
# ### **Diet and Feeding Behavior**
# - **Prey**: Primarily eat **fish** (e.g., cod, halibut), **squid**, and **shrimp**.
# - **Hunting**: Use **echolocation** (clicks and whistles) to locate prey in the dark, icy depths. Their **highly sensitive whiskers** also help detect movement in the water.
#
# ---
#
# ### **Social Behavior and Communication**
# - **Groups**: Travel in **small pods** (usually 10–20 individuals) or **larger herds** during migration.
# - **Communication**: Use a complex array of **clicks, whistles, and knocks** to coordinate movements and socialize.
# - **Mating**: Males may engage in **tusk displays or combat** during mating season, though the exact role of the tusk in courtship is still debated.
#
# ---
#
# ### **Threats and Conservation**
# - **Climate Change**: Melting sea ice and warming waters threaten their habitat and prey availability.
# - **Human Impact**:
#   - **Shipping Noise**: Disrupts their communication and navigation.
#   - **Hunting**: Indigenous communities in Greenland and Canada hunt narwhals for food and cultural purposes, though it’s **regulated** and not a major threat.
# - **Conservation Status**: Listed as **"Near Threatened"** by the IUCN. Efforts focus on **protecting Arctic ecosystems** and **reducing human disturbance**.
#
# ---
#
# ### **Fascinating Facts**
# - **Sensory Superpower**: The tusk’s nerve endings are so sensitive that it can detect **minute changes in the environment**, possibly helping narwhals navigate under ice.
# - **Migration Mystery**: Scientists are still studying why narwhals migrate to specific areas, though it’s likely linked to **food availability** and **breeding**.
# - **Cultural Significance**: In Inuit mythology, narwhals are revered as symbols of **strength and resilience**.
#
# ---
#
# Narwhals are a testament to the adaptability of life in extreme environments. Their unique biology and mysterious behavior continue to captivate scientists and nature lovers alike! 🐋✨

# %% [markdown]
# The state has all of the mesages.
#
# But, let's look at the LangSmith trace to see that the model invocation only uses the last message:
#
# https://smith.langchain.com/public/75aca3ce-ef19-4b92-94be-0178c7a660d9/r

# %% [markdown]
# ## Trim messages
#
# Another approach is to [trim messages](https://docs.langchain.com/oss/python/langgraph/add-memory#trim-messages), based upon a set number of tokens.
#
# This restricts the message history to a specified number of tokens.
#
# While filtering only returns a post-hoc subset of the messages between agents, trimming restricts the number of tokens that a chat model can use to respond.
#
# See the `trim_messages` below.

# %%
from langchain_core.messages import trim_messages

# Node
def chat_model_node(state: MessagesState):
    messages = trim_messages(
            state["messages"],
            max_tokens=100,
            strategy="last",
            token_counter=llm,
            allow_partial=False,
        )
    return {"messages": [llm.invoke(messages)]}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
messages.append(output['messages'][-1])
messages.append(HumanMessage(f"Tell me where Orcas live!", name="Lance"))

# %%
# Example of trimming messages
trim_messages(
    messages,
    max_tokens=100,
    strategy="last",
    token_counter=llm, 
    allow_partial=False
)
# Out:
# /home/user/langchain/3-langgraph_intro/.venv/lib/python3.12/site-packages/langchain_core/language_models/base.py:328: UserWarning: Using fallback GPT-2 tokenizer for token counting. Token counts may be inaccurate for non-GPT-2 models. For accurate counts, use a model-specific method if available.
#   return len(self.get_token_ids(text))
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# [HumanMessage(content='Tell me where Orcas live!', additional_kwargs={}, response_metadata={}, name='Lance')]

# %%
# Invoke, using message trimming in the chat_model_node 
messages_out_trim = graph.invoke({'messages': messages})

# %% [markdown]
# Let's look at the LangSmith trace to see the model invocation:
#
# https://smith.langchain.com/public/b153f7e9-f1a5-4d60-8074-f0d7ab5b42ef/r
